# %% [markdown]
# Sujet Enseignant
#
# #COMMENT FAIRE UN BILAN DE MATIERE AVEC PYTHON ?
#
# ## A. Fiche de présentation
#
# ### 1. Objectif
# On cherche à écrire un programme en python qui permet de faire un bilan de matière.
#
# ### 2.Concepts choisis
# Notion d’avancement, outil du tableau d’avancement.
#
# ### 3. Niveau concerné
# Première spécialité SPC
# « Constitution et transformations de la matière »
# B) Suivi et modélisation de l’évolution d’un système chimique
#
# ### 4. Programme
# * Notion et contenus : Évolution des quantités de matière lors d’une transformation.
# * Capacité numérique : Déterminer la composition de l’état final d’un système siège d’une transformation chimique totale à l’aide d’un langage de programmation.
#
# ### 5. Place de l’activité
# A la fin de la séquence
#
# ### 6. Compétences de la démarche scientifique mobilisées
# * Analyser (ANA) :
# * Proposer une stratégie de résolution
# * Planifier des tâches
# * Réaliser (REA) : Utiliser un modèle
# * Valider (VAL) : Faire preuve d’esprit critique
#
# ### 7. Mise en œuvre de l’activité
#
# Etablir un bilan de matière de la réaction:  $2H_{2~(g)} + O_{2~(g)}  \rightarrow  2H_{2}O_{~(l)}$
#
#
# Le programme de départ demande à l’utilisateur les quantités de matières initiales. Dans un premier temps, on demande d’utiliser le programme pour **vérifier** que l’on a compris le cours. Dans un deuxième temps, on demande des modifications de programme pour **approfondir** les connaissances du cours.
#
# ### 8. Auteurs
# Groupe de réflexion des eemcp2 de SPC, février 2019
#
#
# ---
#
#
# ## B. Sujet
#
# ### 1. Exécution du programme pour illustrer le cours
# 1. Executer le programme ci-dessous, suivre les instructions et observer les affichages dans la console.

# %%
# Bilan de matière de l'équation : 2H2 + O2 -> 2H2O
print("Bonjour, nous allons étudier la réaction entre le dihydrogène H2 et le dioxygène O2")
n1 = float(input("Entrez la valeur de la quantité de matière de dihydrogène en mol : "))
n2 = float(input("Entrez la valeur de la quantité de matière de dioxygène en mol : "))

# quantité de matière du produit à l'état initial
n3 = 0

# hypothèse 1 : H2 est le réactif limitant
if (n1 / 2) < n2:
    xmax = n1 / 2
    n1f = 0
    n2f = n2 - xmax
    print("Le dihydrogène est le réactif limitant.")

# hypothèse 2 : 02 est le réactif limitant
elif (n1 / 2) > n2:
    xmax = n2
    n1f = n1 - 2*xmax
    n2f = 0
    print('Le dioxygène est le réactif limitant.')

# cas où le mélange est stoechiométrique
else:
    xmax = n2
    n1f = 0
    n2f = 0
    print("Les réactifs ont été introduits dans des proportions stoechiométriques.")
    
# quantité de matière du produit à l'état final
n3f = n3 + 2*xmax

# affichage de l'état du système à l'état final
print("A l'état final, la quantité de matière de dihydrogène vaut : ", n1f, " mol")
print("A l'état final, la quantité de matière de dioxygène vaut : ", n2f, " mol")
print("A l'état final, la quantité de matière d'eau vaut : ", n3f, " mol")

# %% [markdown]
# 2. Trouver 3 couples de quantité de matière initiales qui correspondent aux situations suivantes:
#   * a. “l’espèce $H_2$ est le réactif limitant”
#   * b. “l’espèce $O_2$ est le réactif limitant”
#   * c. “le mélange initial est dans les proportions stoechiométriques”

# %% [markdown]
# ### 2. Modification du programme pour approfondir le cours
# 1. Modifier le programme pour qu’il demande les volumes des réactifs en mL puis en L et qu’il puisse les convertir en quantité de matière.
# 2. Modifier le programme pour qu’il étudie la réaction: $3H_{2~(g)} + N_{2~(g)} \rightarrow 2NH_{3~(g)}$
# 3. Modifier le programme pour qu’il étudie la réaction de combustion du méthane: $CH_{4~(g)} + 20_{2~(g)} \rightarrow CO_{2~(g)} + 2H_{2}O_{~(l)}$
# 4.   Modifier le programme pour qu’il étudie la réaction entre l’éthanol et les ions dichromate, en demandant la masse d’éthanol, le volume et la concentration de la solution de dichromate de potassium ajoutée (on fait l’hypothèse que les ions $H^+$ et l’eau sont en excès).
# 5. Modifier le programme pour qu’il visualise l’avancement de la réaction de la production d’ammoniac dans le temps.
#
# Indications pour la question 5.
# * Au début de programme, il faut rajouter :  `from matplotlib import pyplot as plt`
# * A la fin, on crée la variable x en écrivant :  `x=np.linspace (0, xmax, 30)`
# * Puis on demande le tracé de la quantité de chacun des réactifs. Par exemple, pour la quantité d’ammoniac : `plt.plot(x,2*x,'go')` où
# x est l’abscisse, 2*x est l’ordonnée et 'go' est la demande de mettre des ronds verts.
# * A la fin, il faut demander l’affichage du graphique par la commande : `plt.show()`
